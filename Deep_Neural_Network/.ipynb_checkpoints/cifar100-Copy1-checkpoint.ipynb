# %% [raw]
# """
# * FILENAME : cifar100.ipynb
# *
# * DESCRIPTION : classify cifar100 dataset in 100 classes using MLP (Multi-Layer Perceptron)
# *
# * AUTHOR : Kyochul Jang
# * EMAIL: jang128@purdue.edu
# * START DATE : 21 July 2022
# """

# %% [markdown]
# # CIFAR 100

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow import keras 
from keras.layers import Dense

# %% [markdown]
# ## Import Datasets

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()
print(f'$ x_train: {x_train.shape}')
print(f'$ y_train: {y_train.shape}')
print(f'$ x_test: {x_test.shape}')
print(f'$ y_test: {y_test.shape}')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 127s 1us/step
# $ x_train: (50000, 32, 32, 3)
# $ y_train: (50000, 1)
# $ x_test: (10000, 32, 32, 3)
# $ y_test: (10000, 1)

# %% [markdown]
# ## Image Show

# %%
plt.figure(figsize=(10,10))
for idx, img in enumerate(np.random.randint(0, 9999, 25)):
    plt.subplot(5, 5, idx+1)
    plt.imshow(x_train[img])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
plt.show()

# %% [markdown]
# ## Process Data

# %% [markdown]
# ### Normalize Data

# %%
x_train, x_test = x_train/255, x_test/255

# %% [markdown]
# ### Reshape Data

# %%
dim2 = 32*32*3
x_train = x_train.reshape(len(x_train), dim2)
x_test = x_test.reshape(len(x_test), dim2)

# %% [markdown]
# ## Initialize Variables

# %% [markdown]
# ### One-Hot Encoding

# %%
# One-hot Encoding
y_test = pd.get_dummies(i for i in y_test.T[0])
y_train = pd.get_dummies(i for i in y_train.T[0])

# %% [markdown]
# ### Weight && Bias

# %%
W = np.full((3072, 1), 0.0)
b = np.full((100, 1), 0.0)

# %% [markdown]
# ### Hyperparameter

# %%
learning_rate = 0.001
batch_size = 500
epochs = 100

# %% [markdown]
# ## Build Model

# %%
model = keras.Sequential()

# %% [markdown]
# ### Add Layers

# %%
print(f'$ x_train: {x_train.shape}')
print(f'$ y_train: {y_train.shape}')
print(f'$ x_test: {x_test.shape}')
print(f'$ y_test: {y_test.shape}')
# Out:
# $ x_train: (50000, 3072)
# $ y_train: (50000, 100)
# $ x_test: (10000, 3072)
# $ y_test: (10000, 100)

# %% [markdown]
# #### ReLU

# %%
model.add(Dense(1536, activation='relu', input_shape=(3072, )))
model.add(Dense(768, activation='relu', input_shape=(1536, )))
model.add(Dense(512, activation='relu', input_shape=(512, )))
model.add(Dense(512, activation='relu', input_shape=(512, )))
model.add(Dense(512, activation='relu', input_shape=(512, )))
model.add(Dense(256, activation='relu', input_shape=(512, )))
model.add(Dense(128, activation='relu', input_shape=(256, )))

# %% [markdown]
# #### Softmax

# %%
model.add(Dense(100, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1536)              4720128
#
#  dense_1 (Dense)             (None, 768)               1180416
#
#  dense_2 (Dense)             (None, 512)               393728
#
#  dense_3 (Dense)             (None, 512)               262656
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dense_7 (Dense)             (None, 100)               12900
#
# =================================================================
# Total params: 6,996,708
# Trainable params: 6,996,708
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Compile

# %%
adam = keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### Model Train

# %%
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] -
# 100/100 [==============================] - 28s 281ms/step - loss: 2.2258 - accuracy: 0.4101
# Epoch 30/100
# 100/100 [==============================] - 27s 271ms/step - loss: 2.1365 - accuracy: 0.4316
# Epoch 31/100
# 100/100 [==============================] - 28s 282ms/step - loss: 2.0531 - accuracy: 0.4493
# Epoch 32/100
# 100/100 [==============================] - 28s 281ms/step - loss: 1.9722 - accuracy: 0.4695
# Epoch 33/100
# 100/100 [==============================] - 29s 289ms/step - loss: 1.8849 - accuracy: 0.4892
# Epoch 34/100
# 100/100 [==============================] - 28s 281ms/step - loss: 1.7996 - accuracy: 0.5097
# Epoch 35/100
# 100/100 [==============================] - 28s 281ms/step - loss: 1.7404 - accuracy: 0.5236
# Epoch 36/100
# 100/100 [==============================] - 28s 280ms/step - loss: 1.6584 - accuracy: 0.5440
# Epoch 37/100
# 100/100 [==============================] - 28s 275ms/step - loss: 1.5836 - accuracy: 0.5625
# Epoch 38/100
# 100/100 [==============================] - 27s 268ms/step - loss: 1.5028 - accuracy: 0.5831
# Epoch 39/100
# 100/100 [==============================] - 27s 273ms/step - loss: 1.4312 - accuracy: 0.5991
# Epoch 40/100
# 100/100 [==============================] - 27s 273ms/step - loss: 1.3771 - accuracy: 0.6129
# Epoch 41/100
# 100/100 [==============================] - 28s 282ms/step - loss: 1.2883 - accuracy: 0.6376
# Epoch 42/100
# 100/100 [==============================] - 29s 287ms/step - loss: 1.2210 - accuracy: 0.6538
# Epoch 43/100
# 100/100 [==============================] - 28s 284ms/step - loss: 1.1636 - accuracy: 0.6699
# Epoch 44/100
# 100/100 [==============================] - 28s 275ms/step - loss: 1.1188 - accuracy: 0.6803
# Epoch 45/100
# 100/100 [==============================] - 27s 272ms/step - loss: 1.0703 - accuracy: 0.6930
# Epoch 46/100
# 100/100 [==============================] - 20s 202ms/step - loss: 0.9994 - accuracy: 0.7141
# Epoch 47/100
# 100/100 [==============================] - 18s 179ms/step - loss: 0.9542 - accuracy: 0.7223
# Epoch 48/100
# 100/100 [==============================] - 18s 177ms/step - loss: 0.8951 - accuracy: 0.7390
# Epoch 49/100
# 100/100 [==============================] - 17s 175ms/step - loss: 0.8451 - accuracy: 0.7523
# Epoch 50/100
# 100/100 [==============================] - 20s 198ms/step - loss: 0.8102 - accuracy: 0.7637
# Epoch 51/100
# 100/100 [==============================] - 22s 218ms/step - loss: 0.7807 - accuracy: 0.7716
# Epoch 52/100
# 100/100 [==============================] - 25s 252ms/step - loss: 0.7542 - accuracy: 0.7774
# Epoch 53/100
# 100/100 [==============================] - 21s 213ms/step - loss: 0.7068 - accuracy: 0.7891
# Epoch 54/100
# 100/100 [==============================] - 19s 190ms/step - loss: 0.6969 - accuracy: 0.7934
# Epoch 55/100
# 100/100 [==============================] - 19s 191ms/step - loss: 0.6828 - accuracy: 0.7955
# Epoch 56/100
# 100/100 [==============================] - 20s 202ms/step - loss: 0.6171 - accuracy: 0.8160
# Epoch 57/100
# 100/100 [==============================] - 21s 207ms/step - loss: 0.6287 - accuracy: 0.8112
# Epoch 58/100
# 100/100 [==============================] - 25s 254ms/step - loss: 0.5844 - accuracy: 0.8267
# Epoch 59/100
# 100/100 [==============================] - 33s 329ms/step - loss: 0.5747 - accuracy: 0.8279
# Epoch 60/100
# 100/100 [==============================] - 25s 254ms/step - loss: 0.5433 - accuracy: 0.8367
# Epoch 61/100
# 100/100 [==============================] - 22s 219ms/step - loss: 0.5129 - accuracy: 0.8445
# Epoch 62/100
# 100/100 [==============================] - 20s 196ms/step - loss: 0.4743 - accuracy: 0.8555
# Epoch 63/100
# 100/100 [==============================] - 22s 225ms/step - loss: 0.3388 - accuracy: 0.8956
# Epoch 81/100
# 100/100 [==============================] - 25s 251ms/step - loss: 0.2794 - accuracy: 0.9116
# Epoch 82/100
# 100/100 [==============================] - 29s 287ms/step - loss: 0.3595 - accuracy: 0.8912
# Epoch 83/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.3914 - accuracy: 0.8793
# Epoch 84/100
# 100/100 [==============================] - 19s 193ms/step - loss: 0.4611 - accuracy: 0.8618
# Epoch 85/100
# 100/100 [==============================] - 17s 173ms/step - loss: 0.3344 - accuracy: 0.8954
# Epoch 86/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.2671 - accuracy: 0.9183
# Epoch 87/100
# 100/100 [==============================] - 23s 227ms/step - loss: 0.2401 - accuracy: 0.9275
# Epoch 88/100
# 100/100 [==============================] - 25s 251ms/step - loss: 0.2638 - accuracy: 0.9170
# Epoch 89/100
# 100/100 [==============================] - 33s 328ms/step - loss: 0.3564 - accuracy: 0.8925
# Epoch 90/100
# 100/100 [==============================] - 23s 227ms/step - loss: 0.3539 - accuracy: 0.8947
# Epoch 91/100
# 100/100 [==============================] - 20s 198ms/step - loss: 0.3194 - accuracy: 0.9029
# Epoch 92/100
# 100/100 [==============================] - 19s 190ms/step - loss: 0.3493 - accuracy: 0.8963
# Epoch 93/100
# 100/100 [==============================] - 19s 189ms/step - loss: 0.3248 - accuracy: 0.9020
# Epoch 94/100
# 100/100 [==============================] - 24s 243ms/step - loss: 0.2516 - accuracy: 0.9219
# Epoch 95/100
# 100/100 [==============================] - 41s 411ms/step - loss: 0.3262 - accuracy: 0.9023
# Epoch 96/100
# 100/100 [==============================] - 27s 274ms/step - loss: 0.3191 - accuracy: 0.9033
# Epoch 97/100
# 100/100 [==============================] - 23s 234ms/step - loss: 0.2458 - accuracy: 0.9238
# Epoch 98/100
# 100/100 [==============================] - 21s 209ms/step - loss: 0.2610 - accuracy: 0.9193
# Epoch 99/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.2571 - accuracy: 0.9224
# Epoch 100/100
# 100/100 [==============================] - 30s 295ms/step - loss: 0.2599 - accuracy: 0.9221

# %% [markdown]
# ## Predict

# %%
pred = model.predict(x_test)
# Out:
# 313/313 [==============================] - 8s 23ms/step

# %% [markdown]
# ## Test

# %%
count = 0

for idx, i in enumerate(pred):
    if np.argmax(y_test.T[idx]) == np.argmax(i):
        count += 1

# %%
print(len(model.layers[0].get_weights()[0]))
print(model.layers[0].get_weights()[0])
# weights = model.layers[0].get_weights()[0]
# weight_pic = weights.reshape(32, 32, 3)
# Out:
# 3072
# [[-0.01089989 -0.00731453  0.01647008 ... -0.00508529  0.01600418
#    0.00247044]
#  [-0.03277657  0.00802899 -0.04091974 ... -0.02506098 -0.03928933
#    0.02450464]
#  [-0.0327143   0.00270141  0.00472332 ...  0.01103249 -0.01191761
#    0.03513094]
#  ...
#  [-0.02637132 -0.02781149 -0.00974666 ... -0.03062163 -0.03984622
#   -0.01286179]
#  [ 0.00256484 -0.03263798 -0.02748192 ... -0.02086537 -0.01521562
#   -0.00421356]
#  [-0.02405836  0.01044798 -0.01100046 ...  0.02059739  0.00259492
#   -0.0059774 ]]

# %%
len(pred)
# Out:
# 10000
