# %% [raw]
# """
# * FILENAME : cifar100.ipynb
# *
# * DESCRIPTION : classify cifar100 dataset in 100 classes using MLP (Multi-Layer Perceptron)
# *
# * AUTHOR : Kyochul Jang
# * EMAIL: jang128@purdue.edu
# * START DATE : 21 July 2022
# """

# %% [markdown]
# # CIFAR 100

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow import keras 
from keras.layers import Dense

# %% [markdown]
# ## Import Datasets

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()
print(f'$ x_train: {x_train.shape}')
print(f'$ y_train: {y_train.shape}')
print(f'$ x_test: {x_test.shape}')
print(f'$ y_test: {y_test.shape}')
# Out:
# $ x_train: (50000, 32, 32, 3)
# $ y_train: (50000, 1)
# $ x_test: (10000, 32, 32, 3)
# $ y_test: (10000, 1)

# %% [markdown]
# ## Image Show

# %%
plt.figure(figsize=(10,10))
for idx, img in enumerate(np.random.randint(0, 9999, 25)):
    plt.subplot(5, 5, idx+1)
    plt.imshow(x_train[img])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
plt.show()

# %% [markdown]
# ## Process Data

# %% [markdown]
# ### Normalize Data

# %%
x_train, x_test = x_train/255, x_test/255

# %% [markdown]
# ### Reshape Data

# %%
dim2 = 32*32*3
x_train = x_train.reshape(len(x_train), dim2)
x_test = x_test.reshape(len(x_test), dim2)

# %% [markdown]
# ## Initialize Variables

# %% [markdown]
# ### One-Hot Encoding

# %%
# One-hot Encoding
y_test = pd.get_dummies(i for i in y_test.T[0])
y_train = pd.get_dummies(i for i in y_train.T[0])

# %% [markdown]
# ### Weight && Bias

# %%
W = np.full((3072, 1), 0.0)
b = np.full((100, 1), 0.0)

# %% [markdown]
# ### Hyperparameter

# %%
learning_rate = 0.001
batch_size = 500
epochs = 100

# %% [markdown]
# ## Build Model

# %%
model = keras.Sequential()

# %% [markdown]
# ### Add Layers

# %%
print(f'$ x_train: {x_train.shape}')
print(f'$ y_train: {y_train.shape}')
print(f'$ x_test: {x_test.shape}')
print(f'$ y_test: {y_test.shape}')
# Out:
# $ x_train: (50000, 3072)
# $ y_train: (50000, 100)
# $ x_test: (10000, 3072)
# $ y_test: (10000, 100)

# %% [markdown]
# #### ReLU

# %%
model.add(Dense(1536, activation='relu', input_shape=(3072, )))
model.add(Dense(768, activation='relu', input_shape=(1536, )))
model.add(Dense(512, activation='relu', input_shape=(512, )))
model.add(Dense(512, activation='relu', input_shape=(512, )))
model.add(Dense(512, activation='relu', input_shape=(512, )))
model.add(Dense(256, activation='relu', input_shape=(512, )))
model.add(Dense(128, activation='relu', input_shape=(256, )))

# %% [markdown]
# #### Softmax

# %%
model.add(Dense(100, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_87 (Dense)            (None, 1536)              4720128
#
#  dense_88 (Dense)            (None, 768)               1180416
#
#  dense_89 (Dense)            (None, 512)               393728
#
#  dense_90 (Dense)            (None, 512)               262656
#
#  dense_91 (Dense)            (None, 512)               262656
#
#  dense_92 (Dense)            (None, 256)               131328
#
#  dense_93 (Dense)            (None, 128)               32896
#
#  dense_94 (Dense)            (None, 100)               12900
#
# =================================================================
# Total params: 6,996,708
# Trainable params: 6,996,708
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Compile

# %%
adam = keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### Model Train

# %%
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 7s 66ms/step - loss: 4.4479 - accuracy: 0.0266
# Epoch 2/100
# 100/100 [==============================] - 7s 67ms/step - loss: 4.0504 - accuracy: 0.0679
# Epoch 3/100
# 100/100 [==============================] - 6s 65ms/step - loss: 3.9397 - accuracy: 0.0858
# Epoch 4/100
# 100/100 [==============================] - 6s 64ms/step - loss: 3.8255 - accuracy: 0.1041
# Epoch 5/100
# 100/100 [==============================] - 6s 64ms/step - loss: 3.7112 - accuracy: 0.1258
# Epoch 6/100
# 100/100 [==============================] - 6s 65ms/step - loss: 3.6006 - accuracy: 0.1426
# Epoch 7/100
# 100/100 [==============================] - 7s 74ms/step - loss: 3.5057 - accuracy: 0.1630
# Epoch 8/100
# 100/100 [==============================] - 8s 78ms/step - loss: 3.4177 - accuracy: 0.1775
# Epoch 9/100
# 100/100 [==============================] - 7s 65ms/step - loss: 3.3514 - accuracy: 0.1897
# Epoch 10/100
# 100/100 [==============================] - 7s 69ms/step - loss: 3.2859 - accuracy: 0.1984
# Epoch 11/100
# 100/100 [==============================] - 7s 67ms/step - loss: 3.2490 - accuracy: 0.2053
# Epoch 12/100
# 100/100 [==============================] - 7s 65ms/step - loss: 3.1827 - accuracy: 0.2199
# Epoch 13/100
# 100/100 [==============================] - 7s 65ms/step - loss: 3.1296 - accuracy: 0.2284
# Epoch 14/100
# 100/100 [==============================] - 7s 65ms/step - loss: 3.0916 - accuracy: 0.2352
# Epoch 15/100
# 100/100 [==============================] - 7s 65ms/step - loss: 3.0325 - accuracy: 0.2438
# Epoch 16/100
# 100/100 [==============================] - 7s 65ms/step - loss: 2.9892 - accuracy: 0.2538
# Epoch 17/100
# 100/100 [==============================] - 7s 66ms/step - loss: 2.9445 - accuracy: 0.2614
# Epoch 18/100
# 100/100 [==============================] - 6s 65ms/step - loss: 2.8952 - accuracy: 0.2704
# Epoch 19/100
# 100/100 [==============================] - 7s 68ms/step - loss: 2.8370 - accuracy: 0.2826
# Epoch 20/100
# 100/100 [==============================] - 7s 67ms/step - loss: 2.7913 - accuracy: 0.2921
# Epoch 21/100
# 100/100 [==============================] - 7s 65ms/step - loss: 2.7402 - accuracy: 0.3015
# Epoch 22/100
# 100/100 [==============================] - 6s 65ms/step - loss: 2.6604 - accuracy: 0.3178
# Epoch 23/100
# 100/100 [==============================] - 7s 65ms/step - loss: 2.6091 - accuracy: 0.3283
# Epoch 24/100
# 100/100 [==============================] - 7s 65ms/step - loss: 2.5444 - accuracy: 0.3400
# Epoch 25/100
# 100/100 [==============================] - 7s 66ms/step - loss: 2.5023 - accuracy: 0.3497
# Epoch 26/100
# 100/100 [==============================] - 7s 66ms/step - loss: 2.4084 - accuracy: 0.3711
# Epoch 27/100
# 100/100 [==============================] - 7s 66ms/step - loss: 2.3531 - accuracy: 0.3833
# Epoch 28/100
# 100/100 [==============================] - 7s 71ms/step - loss: 2.2943 - accuracy: 0.3960
# Epoch 29/100
# 100/100 [==============================] - 7s 67ms/step - loss: 2.2064 - accuracy: 0.4153
# Epoch 30/100
# 100/100 [==============================] - 7s 65ms/step - loss: 2.1404 - accuracy: 0.4287
# Epoch 31/100
# 100/100 [==============================] - 7s 66ms/step - loss: 2.0387 - accuracy: 0.4539
# Epoch 32/100
# 100/100 [==============================] - 7s 66ms/step - loss: 1.9950 - accuracy: 0.4623
# Epoch 33/100
# 100/100 [==============================] - 7s 66ms/step - loss: 1.9151 - accuracy: 0.4835
# Epoch 34/100
# 100/100 [==============================] - 7s 67ms/step - loss: 1.8046 - accuracy: 0.5087
# Epoch 35/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.7363 - accuracy: 0.5248
# Epoch 36/100
# 100/100 [==============================] - 7s 67ms/step - loss: 1.6904 - accuracy: 0.5364
# Epoch 37/100
# 100/100 [==============================] - 7s 68ms/step - loss: 1.5853 - accuracy: 0.5611
# Epoch 38/100
# 100/100 [==============================] - 7s 70ms/step - loss: 1.5220 - accuracy: 0.5788
# Epoch 39/100
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4582 - accuracy: 0.5951
# Epoch 40/100
# 100/100 [==============================] - 7s 66ms/step - loss: 1.3927 - accuracy: 0.6112
# Epoch 41/100
# 100/100 [==============================] - 7s 66ms/step - loss: 1.3235 - accuracy: 0.6293
# Epoch 42/100
# 100/100 [==============================] - 7s 65ms/step - loss: 1.2958 - accuracy: 0.6335
# Epoch 43/100
# 100/100 [==============================] - 7s 66ms/step - loss: 1.1990 - accuracy: 0.6595
# Epoch 44/100
# 100/100 [==============================] - 7s 66ms/step - loss: 1.1442 - accuracy: 0.6758
# Epoch 45/100
# 100/100 [==============================] - 7s 65ms/step - loss: 1.0715 - accuracy: 0.6938
# Epoch 46/100
# 100/100 [==============================] - 7s 69ms/step - loss: 1.0507 - accuracy: 0.7012
# Epoch 47/100
# 100/100 [==============================] - 7s 69ms/step - loss: 0.9466 - accuracy: 0.7284
# Epoch 48/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.9112 - accuracy: 0.7382
# Epoch 49/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.9132 - accuracy: 0.7327
# Epoch 50/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.8552 - accuracy: 0.7496
# Epoch 51/100
# 100/100 [==============================] - 6s 65ms/step - loss: 0.7608 - accuracy: 0.7762
# Epoch 52/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.7664 - accuracy: 0.7755
# Epoch 53/100
# 100/100 [==============================] - 7s 68ms/step - loss: 0.7805 - accuracy: 0.7705
# Epoch 54/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.7242 - accuracy: 0.7856
# Epoch 55/100
# 100/100 [==============================] - 7s 69ms/step - loss: 0.6523 - accuracy: 0.8091
# Epoch 56/100
# 100/100 [==============================] - 7s 67ms/step - loss: 0.6618 - accuracy: 0.8019
# Epoch 57/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.6242 - accuracy: 0.8126
# Epoch 58/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.5883 - accuracy: 0.8230
# Epoch 59/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.5451 - accuracy: 0.8363
# Epoch 60/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.5935 - accuracy: 0.8213
# Epoch 61/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.5976 - accuracy: 0.8200
# Epoch 62/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.5545 - accuracy: 0.8331
# Epoch 63/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.5194 - accuracy: 0.8457
# Epoch 64/100
# 100/100 [==============================] - 7s 69ms/step - loss: 0.4890 - accuracy: 0.8516
# Epoch 65/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.4798 - accuracy: 0.8566
# Epoch 66/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.4768 - accuracy: 0.8563
# Epoch 67/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.4475 - accuracy: 0.8662
# Epoch 68/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.4725 - accuracy: 0.8566
# Epoch 69/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.4786 - accuracy: 0.8561
# Epoch 70/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.4445 - accuracy: 0.8644
# Epoch 71/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.4274 - accuracy: 0.8707
# Epoch 72/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.3826 - accuracy: 0.8822
# Epoch 73/100
# 100/100 [==============================] - 7s 71ms/step - loss: 0.3869 - accuracy: 0.8822
# Epoch 74/100
# 100/100 [==============================] - 7s 67ms/step - loss: 0.3625 - accuracy: 0.8894
# Epoch 75/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.3913 - accuracy: 0.8801
# Epoch 76/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.3766 - accuracy: 0.8853
# Epoch 77/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.4638 - accuracy: 0.8599
# Epoch 78/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.4240 - accuracy: 0.8732
# Epoch 79/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.3265 - accuracy: 0.8996
# Epoch 80/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.3528 - accuracy: 0.8928
# Epoch 81/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.3460 - accuracy: 0.8960
# Epoch 82/100
# 100/100 [==============================] - 8s 75ms/step - loss: 0.3492 - accuracy: 0.8943
# Epoch 83/100
# 100/100 [==============================] - 7s 67ms/step - loss: 0.3712 - accuracy: 0.8882
# Epoch 84/100
# 100/100 [==============================] - 7s 67ms/step - loss: 0.3412 - accuracy: 0.8949
# Epoch 85/100
# 100/100 [==============================] - 7s 68ms/step - loss: 0.3561 - accuracy: 0.8912
# Epoch 86/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.3085 - accuracy: 0.9068
# Epoch 87/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.3858 - accuracy: 0.8846
# Epoch 88/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.3240 - accuracy: 0.9013
# Epoch 89/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2666 - accuracy: 0.9184
# Epoch 90/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.3039 - accuracy: 0.9086
# Epoch 91/100
# 100/100 [==============================] - 7s 69ms/step - loss: 0.2893 - accuracy: 0.9112
# Epoch 92/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.3282 - accuracy: 0.9007
# Epoch 93/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.3651 - accuracy: 0.8904
# Epoch 94/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.3651 - accuracy: 0.8924
# Epoch 95/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.4364 - accuracy: 0.8723
# Epoch 96/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2397 - accuracy: 0.9268
# Epoch 97/100
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2200 - accuracy: 0.9311
# Epoch 98/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2441 - accuracy: 0.9257
# Epoch 99/100
# 100/100 [==============================] - 7s 66ms/step - loss: 0.3224 - accuracy: 0.9024
# Epoch 100/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.3677 - accuracy: 0.8915

# %% [markdown]
# ## Predict

# %%
pred = model.predict(x_test)
# Out:
# 313/313 [==============================] - 2s 8ms/step

# %% [markdown]
# ## Test

# %%
count = 0

for idx, i in enumerate(pred):
    if np.argmax(y_test.T[idx]) == np.argmax(i):
        count += 1

# %%
print(count)
# Out:
# 2032
